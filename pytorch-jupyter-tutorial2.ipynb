# %% [markdown]
# # 我卷卷卷
#
# 在这节课中，我们学习了如何使用torchvision加载图像库，如何构建一个简单的卷积神经网络，并了解如何训练这个卷积神经网络
# 之后，我们还学会了如何对训练好的卷积网络进行分析

# %%
# 导入所需要的包，请保证torchvision已经在你的环境中安装好.
# 在Windows需要单独安装torchvision包，在命令行运行pip install torchvision即可
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.optim as optim
import torch.nn.functional as F

import torchvision.datasets as dsets
import torchvision.transforms as transforms

import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# ## 一、加载数据

# %% [markdown]
# 1. 首先，我们需要学习PyTorch自带的数据加载器，包括dataset，sampler，以及data loader这三个对象组成的套件。
# 2. 当数据集很小，格式比较规则的时候，数据加载三套件的优势并不明显。但是当数据格式比较特殊，以及数据规模很大（内存无法同时加载所有数据）
# 的时候，特别是，我们需要用不同的处理器来加载数据的时候，三套件的威力就会显现出来了。它会将数据加载、分布的任务自动完成。
# 3. 在使用的时候，我们用dataset来装载数据集，用sampler来采样数据集。而对数据集的迭代、循环则主要通过data_loader来完成。
# 4. 创建一个data_loader就需要一个dataset和一个datasampler，它基本实现的就是利用sampler自动从dataset种采样

# %%
# 定义超参数 
image_size = 28  #图像的总尺寸28*28
num_classes = 10  #标签的种类数
num_epochs = 20  #训练的总循环周期
batch_size = 64  #一个撮（批次）的大小，64张图片

# %%
# 加载MINIST数据，如果没有下载过，就会在当前路径下新建/data子目录，并把文件存放其中
# MNIST数据是属于torchvision包自带的数据，所以可以直接调用。
# 在调用自己的数据的时候，我们可以用torchvision.datasets.ImageFolder或者torch.utils.data.TensorDataset来加载
train_dataset = dsets.MNIST(root='./data',  #文件存放路径
                            train=True,   #提取训练集
                            transform=transforms.ToTensor(),  #将图像转化为Tensor，在加载数据的时候，就可以对图像做预处理
                            download=True) #当找不到文件的时候，自动下载

# 加载测试数据集
test_dataset = dsets.MNIST(root='./data', 
                           train=False, 
                           transform=transforms.ToTensor())

# 训练数据集的加载器，自动将数据分割成batch，顺序随机打乱
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size=batch_size, 
                                           shuffle=True)

'''我们希望将测试数据分成两部分，一部分作为校验数据，一部分作为测试数据。
校验数据用于检测模型是否过拟合，并调整参数，测试数据检验整个模型的工作'''
# Out:
# '我们希望将测试数据分成两部分，一部分作为校验数据，一部分作为测试数据。\n校验数据用于检测模型是否过拟合，并调整参数，测试数据检验整个模型的工作'

# %%
# 首先，我们定义下标数组indices，它相当于对所有test_dataset中数据的编码
# 然后定义下标indices_val来表示校验集数据的那些下标，indices_test表示测试集的下标
indices = range(len(test_dataset))
indices_val = indices[:5000]
indices_test = indices[5000:]

# 根据这些下标，构造两个数据集的SubsetRandomSampler采样器，它会对下标进行采样
sampler_val = torch.utils.data.sampler.SubsetRandomSampler(indices_val)
sampler_test = torch.utils.data.sampler.SubsetRandomSampler(indices_test)

# 根据两个采样器来定义加载器，注意将sampler_val和sampler_test分别赋值给了validation_loader和test_loader
validation_loader = torch.utils.data.DataLoader(dataset =test_dataset,
                                                batch_size = batch_size,
                                                sampler = sampler_val
                                               )
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, 
                                          batch_size=batch_size, 
                                          sampler = sampler_test
                                         )

# %%
#随便从数据集中读入一张图片，并绘制出来
idx = 1000

#dataset支持下标索引，其中提取出来的每一个元素为features，target格式，即属性和标签。[0]表示索引features
muteimg = train_dataset[idx][0].numpy()
#由于一般的图像包含rgb三个通道，而MINST数据集的图像都是灰度的，只有一个通道。因此，我们忽略通道，把图像看作一个灰度矩阵。
#用imshow画图，会将灰度矩阵自动展现为彩色，不同灰度对应不同颜色：从黄到紫

plt.imshow(muteimg[0,...])
print('标签是：',train_dataset[idx][1])
# Out:
# 标签是： 0

# %% [markdown]
# ## 二、基本的卷积神经网络

# %% [markdown]
# ### 2.1 构建网络

# %% [markdown]
# 注：在这里，我们将主要调用PyTorch强大的nn.Module这个类来构建卷积神经网络。我们分成如下这几个步骤：
#
# 1. 首先，我们构造ConvNet类，它是对类nn.Module的继承（即nn.Module是父类，ConvNet为子类。如果这些概念不熟悉，请参考面向对象编程）
# 2. 然后，我们复写__init__，以及forward这两个函数。第一个为构造函数，每当类ConvNet被具体化一个实例的时候，就会调用，forward则是
# 在运行神经网络正向的时候会被自动调用
# 3. 自定义自己的方法
#
# 另一需要理解的是，ConvNet其实也是一个大容器，它里面有Conv2d，MaxPool2d等组件

# %%
#定义卷积神经网络：4和8为人为指定的两个卷积层的厚度（feature map的数量）
depth = [4, 8]
class ConvNet(nn.Module):
    def __init__(self):
        # 该函数在创建一个ConvNet对象的时候，即调用如下语句：net=ConvNet()，就会被调用
        # 首先调用父类相应的构造函数
        super(ConvNet, self).__init__()
        
        # 其次构造ConvNet需要用到的各个神经模块。
        '''注意，定义组件并没有真正搭建这些组件，只是把基本建筑砖块先找好'''
        self.conv1 = nn.Conv2d(1, 4, 5, padding = 2) #定义一个卷积层，输入通道为1，输出通道为4，窗口大小为5，padding为2
        self.pool = nn.MaxPool2d(2, 2) #定义一个Pooling层，一个窗口为2*2的pooling运算
        self.conv2 = nn.Conv2d(depth[0], depth[1], 5, padding = 2) #第二层卷积，输入通道为depth[0], 
                                                                   #输出通道为depth[1]，窗口为5，padding为2
        self.fc1 = nn.Linear(image_size // 4 * image_size // 4 * depth[1] , 512) 
                                                            #一个线性连接层，输入尺寸为最后一层立方体的平铺，输出层512个节点
        self.fc2 = nn.Linear(512, num_classes) #最后一层线性分类单元，输入为512，输出为要做分类的类别数

    def forward(self, x):
        #该函数完成神经网络真正的前向运算，我们会在这里把各个组件进行实际的拼装
        #x的尺寸：(batch_size, image_channels, image_width, image_height)
        x = F.relu(self.conv1(x))  #第一层卷积，激活函数用ReLu，为了防止过拟合
        #x的尺寸：(batch_size, num_filters, image_width, image_height)
        x = self.pool(x) #第二层pooling，将图片变小
        #x的尺寸：(batch_size, depth[0], image_width/2, image_height/2)
        x = F.relu(self.conv2(x)) #第三层又是卷积，窗口为5，输入输出通道分别为depth[0]=4, depth[1]=8
        #x的尺寸：(batch_size, depth[1], image_width/2, image_height/2)
        x = self.pool(x) #第四层pooling，将图片缩小到原大小的1/4
        #x的尺寸：(batch_size, depth[1], image_width/4, image_height/4)
        
        # 将立体的特征图Tensor，压成一个一维的向量
        # view这个函数可以将一个tensor按指定的方式重新排布。
        # 下面这个命令就是要让x按照batch_size * (image_size//4)^2*depth[1]的方式来排布向量
        x = x.view(-1, image_size // 4 * image_size // 4 * depth[1])
        #x的尺寸：(batch_size, depth[1]*image_width/4*image_height/4)
        
        x = F.relu(self.fc1(x)) #第五层为全链接，ReLu激活函数
        #x的尺寸：(batch_size, 512)

        x = F.dropout(x, training=self.training) #以默认为0.5的概率对这一层进行dropout操作，为了防止过拟合
        x = self.fc2(x) #全链接
        #x的尺寸：(batch_size, num_classes)
        
        x = F.log_softmax(x, dim = 0) #输出层为log_softmax，即概率对数值log(p(x))。采用log_softmax可以使得后面的交叉熵计算更快
        return x
    
    def retrieve_features(self, x):
        #该函数专门用于提取卷积神经网络的特征图的功能，返回feature_map1, feature_map2为前两层卷积层的特征图
        feature_map1 = F.relu(self.conv1(x)) #完成第一层卷积
        x = self.pool(feature_map1)  # 完成第一层pooling
        feature_map2 = F.relu(self.conv2(x)) #第二层卷积，两层特征图都存储到了feature_map1, feature_map2中
        return (feature_map1, feature_map2)

# %% [markdown]
# ### 2.2 训练这个卷积神经网络

# %%
def rightness(predictions, labels):
    """计算预测错误率的函数，其中predictions是模型给出的一组预测结果，batch_size行num_classes列的矩阵，labels是数据之中的正确答案"""
    pred = torch.max(predictions.data, 1)[1] # 对于任意一行（一个样本）的输出值的第1个维度，求最大，得到每一行的最大元素的下标
    rights = pred.eq(labels.data.view_as(pred)).sum() #将下标与labels中包含的类别进行比较，并累计得到比较正确的数量
    return rights, len(labels) #返回正确的数量和这一次一共比较了多少元素

# %%
net = ConvNet() #新建一个卷积神经网络的实例，此时ConvNet的__init__函数就会被自动调用

criterion = nn.CrossEntropyLoss() #Loss函数的定义，交叉熵
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9) #定义优化器，普通的随机梯度下降算法

record = [] #记录准确率等数值的容器
weights = [] #每若干步就记录一次卷积核

#开始训练循环
for epoch in range(num_epochs):
    
    train_rights = [] #记录训练数据集准确率的容器
    
    ''' 下面的enumerate是构造一个枚举器的作用。就是我们在对train_loader做循环迭代的时候，enumerate会自动吐出一个数字指示我们循环了几次
     这个数字就被记录在了batch_idx之中，它就等于0，1，2，……
     train_loader每迭代一次，就会吐出来一对数据data和target，分别对应着一个batch中的手写数字图，以及对应的标签。'''
    
    for batch_idx, (data, target) in enumerate(train_loader):  #针对容器中的每一个批进行循环
        data, target = data.clone().requires_grad_(True), target.clone().detach()  #data为一批图像，target为一批标签
        net.train() # 给网络模型做标记，标志说模型正在训练集上训练，
                    #这种区分主要是为了打开关闭net的training标志，从而决定是否运行dropout
            
        output = net(data) #神经网络完成一次前馈的计算过程，得到预测输出output
        loss = criterion(output, target) #将output与标签target比较，计算误差
        optimizer.zero_grad() #清空梯度
        loss.backward() #反向传播
        optimizer.step() #一步随机梯度下降算法
        right = rightness(output, target) #计算准确率所需数值，返回数值为（正确样例数，总样本数）
        train_rights.append(right) #将计算结果装到列表容器train_rights中

    
        if batch_idx % 100 == 0: #每间隔100个batch执行一次打印等操作
            
            net.eval() # 给网络模型做标记，标志说模型在训练集上训练
            val_rights = [] #记录校验数据集准确率的容器
            
            '''开始在校验数据集上做循环，计算校验集上面的准确度'''
            for (data, target) in validation_loader:
                data, target = data.clone().requires_grad_(True), target.clone().detach()
                output = net(data) #完成一次前馈计算过程，得到目前训练得到的模型net在校验数据集上的表现
                right = rightness(output, target) #计算准确率所需数值，返回正确的数值为（正确样例数，总样本数）
                val_rights.append(right)
            
            # 分别计算在目前已经计算过的测试数据集，以及全部校验集上模型的表现：分类准确率
            #train_r为一个二元组，分别记录目前已经经历过的所有训练集中分类正确的数量和该集合中总的样本数，
            #train_r[0]/train_r[1]就是训练集的分类准确度，同样，val_r[0]/val_r[1]就是校验集上的分类准确度
            train_r = (sum([tup[0] for tup in train_rights]), sum([tup[1] for tup in train_rights]))
            #val_r为一个二元组，分别记录校验集中分类正确的数量和该集合中总的样本数
            val_r = (sum([tup[0] for tup in val_rights]), sum([tup[1] for tup in val_rights]))
            #打印准确率等数值，其中正确率为本训练周期Epoch开始后到目前撮的正确率的平均值
            print(val_r)
            print('训练周期: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}\t训练正确率: {:.2f}%\t校验正确率: {:.2f}%'.format(
                epoch, batch_idx * batch_size, len(train_loader.dataset),
                100. * batch_idx / len(train_loader), 
                loss.data, 
                100. * train_r[0].numpy() / train_r[1], 
                100. * val_r[0].numpy() / val_r[1]))
            
            #将准确率和权重等数值加载到容器中，以方便后续处理
            record.append((100 - 100. * train_r[0] / train_r[1], 100 - 100. * val_r[0] / val_r[1]))
            
            # weights记录了训练周期中所有卷积核的演化过程。net.conv1.weight就提取出了第一层卷积核的权重
            # clone的意思就是将weight.data中的数据做一个拷贝放到列表中，否则当weight.data变化的时候，列表中的每一项数值也会联动
            '''这里使用clone这个函数很重要'''
            weights.append([net.conv1.weight.data.clone(), net.conv1.bias.data.clone(), 
                            net.conv2.weight.data.clone(), net.conv2.bias.data.clone()])
# Out:
# (tensor(458), 5000)
# 训练周期: 0 [0/60000 (0%)]	Loss: 2.300383	训练正确率: 7.81%	校验正确率: 9.16%
# (tensor(1114), 5000)
# 训练周期: 0 [6400/60000 (11%)]	Loss: 2.300909	训练正确率: 10.78%	校验正确率: 22.28%
# (tensor(1767), 5000)
# 训练周期: 0 [12800/60000 (21%)]	Loss: 2.302252	训练正确率: 12.38%	校验正确率: 35.34%
# (tensor(2188), 5000)
# 训练周期: 0 [19200/60000 (32%)]	Loss: 2.294771	训练正确率: 13.94%	校验正确率: 43.76%
# (tensor(2506), 5000)
# 训练周期: 0 [25600/60000 (43%)]	Loss: 2.285215	训练正确率: 16.09%	校验正确率: 50.12%
# (tensor(2791), 5000)
# 训练周期: 0 [32000/60000 (53%)]	Loss: 2.265909	训练正确率: 18.63%	校验正确率: 55.82%
# (tensor(2898), 5000)
# 训练周期: 0 [38400/60000 (64%)]	Loss: 2.235699	训练正确率: 21.40%	校验正确率: 57.96%
# (tensor(3048), 5000)
# 训练周期: 0 [44800/60000 (75%)]	Loss: 2.004954	训练正确率: 24.28%	校验正确率: 60.96%
# (tensor(3564), 5000)
# 训练周期: 0 [51200/60000 (85%)]	Loss: 1.227656	训练正确率: 28.10%	校验正确率: 71.28%
# (tensor(3871), 5000)
# 训练周期: 0 [57600/60000 (96%)]	Loss: 0.950835	训练正确率: 32.54%	校验正确率: 77.42%
# (tensor(3912), 5000)
# 训练周期: 1 [0/60000 (0%)]	Loss: 0.923946	训练正确率: 67.19%	校验正确率: 78.24%
# (tensor(4042), 5000)
# 训练周期: 1 [6400/60000 (11%)]	Loss: 0.646357	训练正确率: 74.41%	校验正确率: 80.84%
# (tensor(4094), 5000)
# 训练周期: 1 [12800/60000 (21%)]	Loss: 0.609655	训练正确率: 76.36%	校验正确率: 81.88%
# (tensor(4178), 5000)
# 训练周期: 1 [19200/60000 (32%)]	Loss: 0.529142	训练正确率: 77.44%	校验正确率: 83.56%
# (tensor(4278), 5000)
# 训练周期: 1 [25600/60000 (43%)]	Loss: 0.521243	训练正确率: 78.71%	校验正确率: 85.56%
# (tensor(4292), 5000)
# 训练周期: 1 [32000/60000 (53%)]	Loss: 0.437715	训练正确率: 79.47%	校验正确率: 85.84%
# (tensor(4335), 5000)
# 训练周期: 1 [38400/60000 (64%)]	Loss: 0.364464	训练正确率: 80.35%	校验正确率: 86.70%
# (tensor(4377), 5000)
# 训练周期: 1 [44800/60000 (75%)]	Loss: 0.423580	训练正确率: 81.02%	校验正确率: 87.54%
# (tensor(4413), 5000)
# 训练周期: 1 [51200/60000 (85%)]	Loss: 0.589082	训练正确率: 81.61%	校验正确率: 88.26%
# (tensor(4449), 5000)
# 训练周期: 1 [57600/60000 (96%)]	Loss: 0.256935	训练正确率: 82.24%	校验正确率: 88.98%
# (tensor(4450), 5000)
# 训练周期: 2 [0/60000 (0%)]	Loss: 0.357021	训练正确率: 89.06%	校验正确率: 89.00%
# (tensor(4491), 5000)
# 训练周期: 2 [6400/60000 (11%)]	Loss: 0.503936	训练正确率: 87.69%	校验正确率: 89.82%
# (tensor(4524), 5000)
# 训练周期: 2 [12800/60000 (21%)]	Loss: 0.400018	训练正确率: 88.04%	校验正确率: 90.48%
# (tensor(4510), 5000)
# 训练周期: 2 [19200/60000 (32%)]	Loss: 0.234673	训练正确率: 88.24%	校验正确率: 90.20%
# (tensor(4546), 5000)
# 训练周期: 2 [25600/60000 (43%)]	Loss: 0.165340	训练正确率: 88.37%	校验正确率: 90.92%
# (tensor(4583), 5000)
# 训练周期: 2 [32000/60000 (53%)]	Loss: 0.302789	训练正确率: 88.64%	校验正确率: 91.66%
# (tensor(4580), 5000)
# 训练周期: 2 [38400/60000 (64%)]	Loss: 0.469577	训练正确率: 88.86%	校验正确率: 91.60%
# (tensor(4607), 5000)
# 训练周期: 2 [44800/60000 (75%)]	Loss: 0.243580	训练正确率: 89.12%	校验正确率: 92.14%
# (tensor(4609), 5000)
# 训练周期: 2 [51200/60000 (85%)]	Loss: 0.292866	训练正确率: 89.37%	校验正确率: 92.18%
# (tensor(4616), 5000)
# 训练周期: 2 [57600/60000 (96%)]	Loss: 0.415995	训练正确率: 89.66%	校验正确率: 92.32%
# (tensor(4641), 5000)
# 训练周期: 3 [0/60000 (0%)]	Loss: 0.283985	训练正确率: 90.62%	校验正确率: 92.82%
# (tensor(4649), 5000)
# 训练周期: 3 [6400/60000 (11%)]	Loss: 0.192495	训练正确率: 91.96%	校验正确率: 92.98%
# (tensor(4657), 5000)
# 训练周期: 3 [12800/60000 (21%)]	Loss: 0.243428	训练正确率: 91.91%	校验正确率: 93.14%
# (tensor(4661), 5000)
# 训练周期: 3 [19200/60000 (32%)]	Loss: 0.219931	训练正确率: 92.28%	校验正确率: 93.22%
# (tensor(4660), 5000)
# 训练周期: 3 [25600/60000 (43%)]	Loss: 0.152939	训练正确率: 92.36%	校验正确率: 93.20%
# (tensor(4661), 5000)
# 训练周期: 3 [32000/60000 (53%)]	Loss: 0.334574	训练正确率: 92.39%	校验正确率: 93.22%
# (tensor(4689), 5000)
# 训练周期: 3 [38400/60000 (64%)]	Loss: 0.329573	训练正确率: 92.49%	校验正确率: 93.78%
# (tensor(4684), 5000)
# 训练周期: 3 [44800/60000 (75%)]	Loss: 0.174923	训练正确率: 92.54%	校验正确率: 93.68%
# (tensor(4711), 5000)
# 训练周期: 3 [51200/60000 (85%)]	Loss: 0.144484	训练正确率: 92.68%	校验正确率: 94.22%
# (tensor(4703), 5000)
# 训练周期: 3 [57600/60000 (96%)]	Loss: 0.105236	训练正确率: 92.77%	校验正确率: 94.06%
# (tensor(4700), 5000)
# 训练周期: 4 [0/60000 (0%)]	Loss: 0.330335	训练正确率: 93.75%	校验正确率: 94.00%
# (tensor(4734), 5000)
# 训练周期: 4 [6400/60000 (11%)]	Loss: 0.162198	训练正确率: 93.75%	校验正确率: 94.68%
# (tensor(4706), 5000)
# 训练周期: 4 [12800/60000 (21%)]	Loss: 0.409992	训练正确率: 93.53%	校验正确率: 94.12%
# (tensor(4721), 5000)
# 训练周期: 4 [19200/60000 (32%)]	Loss: 0.131823	训练正确率: 93.73%	校验正确率: 94.42%
# (tensor(4736), 5000)
# 训练周期: 4 [25600/60000 (43%)]	Loss: 0.237615	训练正确率: 93.75%	校验正确率: 94.72%
# (tensor(4744), 5000)
# 训练周期: 4 [32000/60000 (53%)]	Loss: 0.141341	训练正确率: 93.82%	校验正确率: 94.88%
# (tensor(4742), 5000)
# 训练周期: 4 [38400/60000 (64%)]	Loss: 0.194211	训练正确率: 93.86%	校验正确率: 94.84%
# (tensor(4758), 5000)
# 训练周期: 4 [44800/60000 (75%)]	Loss: 0.174790	训练正确率: 93.84%	校验正确率: 95.16%
# (tensor(4765), 5000)
# 训练周期: 4 [51200/60000 (85%)]	Loss: 0.198742	训练正确率: 93.94%	校验正确率: 95.30%
# (tensor(4742), 5000)
# 训练周期: 4 [57600/60000 (96%)]	Loss: 0.134965	训练正确率: 93.99%	校验正确率: 94.84%
# (tensor(4749), 5000)
# 训练周期: 5 [0/60000 (0%)]	Loss: 0.144466	训练正确率: 93.75%	校验正确率: 94.98%
# (tensor(4758), 5000)
# 训练周期: 5 [6400/60000 (11%)]	Loss: 0.217162	训练正确率: 94.57%	校验正确率: 95.16%
# (tensor(4777), 5000)
# 训练周期: 5 [12800/60000 (21%)]	Loss: 0.150380	训练正确率: 94.57%	校验正确率: 95.54%
# (tensor(4768), 5000)
# 训练周期: 5 [19200/60000 (32%)]	Loss: 0.115117	训练正确率: 94.63%	校验正确率: 95.36%
# (tensor(4760), 5000)
# 训练周期: 5 [25600/60000 (43%)]	Loss: 0.198845	训练正确率: 94.57%	校验正确率: 95.20%
# (tensor(4770), 5000)
# 训练周期: 5 [32000/60000 (53%)]	Loss: 0.118531	训练正确率: 94.69%	校验正确率: 95.40%
# (tensor(4765), 5000)
# 训练周期: 5 [38400/60000 (64%)]	Loss: 0.133846	训练正确率: 94.69%	校验正确率: 95.30%
# (tensor(4781), 5000)
# 训练周期: 5 [44800/60000 (75%)]	Loss: 0.118188	训练正确率: 94.77%	校验正确率: 95.62%
# (tensor(4758), 5000)
# 训练周期: 5 [51200/60000 (85%)]	Loss: 0.158600	训练正确率: 94.79%	校验正确率: 95.16%
# (tensor(4775), 5000)
# 训练周期: 5 [57600/60000 (96%)]	Loss: 0.097241	训练正确率: 94.88%	校验正确率: 95.50%
# (tensor(4787), 5000)
# 训练周期: 6 [0/60000 (0%)]	Loss: 0.126500	训练正确率: 95.31%	校验正确率: 95.74%
# (tensor(4806), 5000)
# 训练周期: 6 [6400/60000 (11%)]	Loss: 0.205923	训练正确率: 94.77%	校验正确率: 96.12%
# (tensor(4778), 5000)
# 训练周期: 6 [12800/60000 (21%)]	Loss: 0.352272	训练正确率: 95.06%	校验正确率: 95.56%
# (tensor(4785), 5000)
# 训练周期: 6 [19200/60000 (32%)]	Loss: 0.257809	训练正确率: 95.13%	校验正确率: 95.70%
# (tensor(4785), 5000)
# 训练周期: 6 [25600/60000 (43%)]	Loss: 0.395056	训练正确率: 95.26%	校验正确率: 95.70%
# (tensor(4800), 5000)
# 训练周期: 6 [32000/60000 (53%)]	Loss: 0.090081	训练正确率: 95.30%	校验正确率: 96.00%
# (tensor(4800), 5000)
# 训练周期: 6 [38400/60000 (64%)]	Loss: 0.203557	训练正确率: 95.39%	校验正确率: 96.00%
# (tensor(4810), 5000)
# 训练周期: 6 [44800/60000 (75%)]	Loss: 0.287293	训练正确率: 95.50%	校验正确率: 96.20%
# (tensor(4784), 5000)
# 训练周期: 6 [51200/60000 (85%)]	Loss: 0.134419	训练正确率: 95.50%	校验正确率: 95.68%
# (tensor(4822), 5000)
# 训练周期: 6 [57600/60000 (96%)]	Loss: 0.135356	训练正确率: 95.53%	校验正确率: 96.44%
# (tensor(4809), 5000)
# 训练周期: 7 [0/60000 (0%)]	Loss: 0.131846	训练正确率: 95.31%	校验正确率: 96.18%
# (tensor(4798), 5000)
# 训练周期: 7 [6400/60000 (11%)]	Loss: 0.066433	训练正确率: 96.01%	校验正确率: 95.96%
# (tensor(4814), 5000)
# 训练周期: 7 [12800/60000 (21%)]	Loss: 0.099887	训练正确率: 95.87%	校验正确率: 96.28%
# (tensor(4820), 5000)
# 训练周期: 7 [19200/60000 (32%)]	Loss: 0.137377	训练正确率: 95.94%	校验正确率: 96.40%
# (tensor(4806), 5000)
# 训练周期: 7 [25600/60000 (43%)]	Loss: 0.068623	训练正确率: 95.87%	校验正确率: 96.12%
# (tensor(4819), 5000)
# 训练周期: 7 [32000/60000 (53%)]	Loss: 0.257406	训练正确率: 95.88%	校验正确率: 96.38%
# (tensor(4837), 5000)
# 训练周期: 7 [38400/60000 (64%)]	Loss: 0.385155	训练正确率: 95.94%	校验正确率: 96.74%
# (tensor(4809), 5000)
# 训练周期: 7 [44800/60000 (75%)]	Loss: 0.138241	训练正确率: 96.01%	校验正确率: 96.18%
# (tensor(4816), 5000)
# 训练周期: 7 [51200/60000 (85%)]	Loss: 0.043518	训练正确率: 96.03%	校验正确率: 96.32%
# (tensor(4828), 5000)
# 训练周期: 7 [57600/60000 (96%)]	Loss: 0.134091	训练正确率: 95.97%	校验正确率: 96.56%
# (tensor(4829), 5000)
# 训练周期: 8 [0/60000 (0%)]	Loss: 0.075398	训练正确率: 98.44%	校验正确率: 96.58%
# (tensor(4820), 5000)
# 训练周期: 8 [6400/60000 (11%)]	Loss: 0.064864	训练正确率: 96.23%	校验正确率: 96.40%
# (tensor(4810), 5000)
# 训练周期: 8 [12800/60000 (21%)]	Loss: 0.102543	训练正确率: 96.32%	校验正确率: 96.20%
# (tensor(4817), 5000)
# 训练周期: 8 [19200/60000 (32%)]	Loss: 0.043551	训练正确率: 96.22%	校验正确率: 96.34%
# (tensor(4849), 5000)
# 训练周期: 8 [25600/60000 (43%)]	Loss: 0.266331	训练正确率: 96.18%	校验正确率: 96.98%
# (tensor(4832), 5000)
# 训练周期: 8 [32000/60000 (53%)]	Loss: 0.121991	训练正确率: 96.19%	校验正确率: 96.64%
# (tensor(4831), 5000)
# 训练周期: 8 [38400/60000 (64%)]	Loss: 0.113183	训练正确率: 96.27%	校验正确率: 96.62%
# (tensor(4838), 5000)
# 训练周期: 8 [44800/60000 (75%)]	Loss: 0.318317	训练正确率: 96.34%	校验正确率: 96.76%
# (tensor(4830), 5000)
# 训练周期: 8 [51200/60000 (85%)]	Loss: 0.092446	训练正确率: 96.35%	校验正确率: 96.60%
# (tensor(4830), 5000)
# 训练周期: 8 [57600/60000 (96%)]	Loss: 0.154846	训练正确率: 96.32%	校验正确率: 96.60%
# (tensor(4834), 5000)
# 训练周期: 9 [0/60000 (0%)]	Loss: 0.120837	训练正确率: 95.31%	校验正确率: 96.68%
# (tensor(4834), 5000)
# 训练周期: 9 [6400/60000 (11%)]	Loss: 0.118880	训练正确率: 96.27%	校验正确率: 96.68%
# (tensor(4829), 5000)
# 训练周期: 9 [12800/60000 (21%)]	Loss: 0.043149	训练正确率: 96.32%	校验正确率: 96.58%
# (tensor(4847), 5000)
# 训练周期: 9 [19200/60000 (32%)]	Loss: 0.092127	训练正确率: 96.41%	校验正确率: 96.94%
# (tensor(4847), 5000)
# 训练周期: 9 [25600/60000 (43%)]	Loss: 0.114205	训练正确率: 96.52%	校验正确率: 96.94%
# (tensor(4839), 5000)
# 训练周期: 9 [32000/60000 (53%)]	Loss: 0.029293	训练正确率: 96.62%	校验正确率: 96.78%
# (tensor(4843), 5000)
# 训练周期: 9 [38400/60000 (64%)]	Loss: 0.044374	训练正确率: 96.62%	校验正确率: 96.86%
# (tensor(4843), 5000)
# 训练周期: 9 [44800/60000 (75%)]	Loss: 0.036173	训练正确率: 96.71%	校验正确率: 96.86%
# (tensor(4851), 5000)
# 训练周期: 9 [51200/60000 (85%)]	Loss: 0.065519	训练正确率: 96.69%	校验正确率: 97.02%
# (tensor(4844), 5000)
# 训练周期: 9 [57600/60000 (96%)]	Loss: 0.047481	训练正确率: 96.69%	校验正确率: 96.88%
# (tensor(4850), 5000)
# 训练周期: 10 [0/60000 (0%)]	Loss: 0.566779	训练正确率: 84.38%	校验正确率: 97.00%
# (tensor(4848), 5000)
# 训练周期: 10 [6400/60000 (11%)]	Loss: 0.135159	训练正确率: 96.52%	校验正确率: 96.96%
# (tensor(4842), 5000)
# 训练周期: 10 [12800/60000 (21%)]	Loss: 0.132811	训练正确率: 96.52%	校验正确率: 96.84%
# (tensor(4846), 5000)
# 训练周期: 10 [19200/60000 (32%)]	Loss: 0.026699	训练正确率: 96.64%	校验正确率: 96.92%
# (tensor(4859), 5000)
# 训练周期: 10 [25600/60000 (43%)]	Loss: 0.043127	训练正确率: 96.69%	校验正确率: 97.18%
# (tensor(4843), 5000)
# 训练周期: 10 [32000/60000 (53%)]	Loss: 0.106295	训练正确率: 96.63%	校验正确率: 96.86%
# (tensor(4857), 5000)
# 训练周期: 10 [38400/60000 (64%)]	Loss: 0.052384	训练正确率: 96.67%	校验正确率: 97.14%
# (tensor(4853), 5000)
# 训练周期: 10 [44800/60000 (75%)]	Loss: 0.173167	训练正确率: 96.69%	校验正确率: 97.06%
# (tensor(4862), 5000)
# 训练周期: 10 [51200/60000 (85%)]	Loss: 0.102061	训练正确率: 96.74%	校验正确率: 97.24%
# (tensor(4858), 5000)
# 训练周期: 10 [57600/60000 (96%)]	Loss: 0.067873	训练正确率: 96.75%	校验正确率: 97.16%
# (tensor(4863), 5000)
# 训练周期: 11 [0/60000 (0%)]	Loss: 0.058911	训练正确率: 98.44%	校验正确率: 97.26%
# (tensor(4865), 5000)
# 训练周期: 11 [6400/60000 (11%)]	Loss: 0.153815	训练正确率: 97.49%	校验正确率: 97.30%
# (tensor(4843), 5000)
# 训练周期: 11 [12800/60000 (21%)]	Loss: 0.071305	训练正确率: 97.08%	校验正确率: 96.86%
# (tensor(4872), 5000)
# 训练周期: 11 [19200/60000 (32%)]	Loss: 0.084144	训练正确率: 97.17%	校验正确率: 97.44%
# (tensor(4871), 5000)
# 训练周期: 11 [25600/60000 (43%)]	Loss: 0.217536	训练正确率: 97.14%	校验正确率: 97.42%
# (tensor(4852), 5000)
# 训练周期: 11 [32000/60000 (53%)]	Loss: 0.066660	训练正确率: 97.10%	校验正确率: 97.04%
# (tensor(4849), 5000)
# 训练周期: 11 [38400/60000 (64%)]	Loss: 0.153635	训练正确率: 97.02%	校验正确率: 96.98%
# (tensor(4862), 5000)
# 训练周期: 11 [44800/60000 (75%)]	Loss: 0.103432	训练正确率: 97.02%	校验正确率: 97.24%
# (tensor(4864), 5000)
# 训练周期: 11 [51200/60000 (85%)]	Loss: 0.148874	训练正确率: 96.99%	校验正确率: 97.28%
# (tensor(4872), 5000)
# 训练周期: 11 [57600/60000 (96%)]	Loss: 0.027306	训练正确率: 97.01%	校验正确率: 97.44%
# (tensor(4861), 5000)
# 训练周期: 12 [0/60000 (0%)]	Loss: 0.044857	训练正确率: 100.00%	校验正确率: 97.22%
# (tensor(4864), 5000)
# 训练周期: 12 [6400/60000 (11%)]	Loss: 0.013273	训练正确率: 97.35%	校验正确率: 97.28%
# (tensor(4867), 5000)
# 训练周期: 12 [12800/60000 (21%)]	Loss: 0.033248	训练正确率: 97.27%	校验正确率: 97.34%
# (tensor(4859), 5000)
# 训练周期: 12 [19200/60000 (32%)]	Loss: 0.219681	训练正确率: 97.21%	校验正确率: 97.18%
# (tensor(4863), 5000)
# 训练周期: 12 [25600/60000 (43%)]	Loss: 0.042114	训练正确率: 97.08%	校验正确率: 97.26%
# (tensor(4881), 5000)
# 训练周期: 12 [32000/60000 (53%)]	Loss: 0.072919	训练正确率: 96.99%	校验正确率: 97.62%
# (tensor(4867), 5000)
# 训练周期: 12 [38400/60000 (64%)]	Loss: 0.016050	训练正确率: 97.03%	校验正确率: 97.34%
# (tensor(4855), 5000)
# 训练周期: 12 [44800/60000 (75%)]	Loss: 0.050293	训练正确率: 97.02%	校验正确率: 97.10%
# (tensor(4855), 5000)
# 训练周期: 12 [51200/60000 (85%)]	Loss: 0.141594	训练正确率: 97.00%	校验正确率: 97.10%
# (tensor(4873), 5000)
# 训练周期: 12 [57600/60000 (96%)]	Loss: 0.220298	训练正确率: 97.02%	校验正确率: 97.46%
# (tensor(4861), 5000)
# 训练周期: 13 [0/60000 (0%)]	Loss: 0.067980	训练正确率: 96.88%	校验正确率: 97.22%
# (tensor(4870), 5000)
# 训练周期: 13 [6400/60000 (11%)]	Loss: 0.108126	训练正确率: 97.37%	校验正确率: 97.40%
# (tensor(4874), 5000)
# 训练周期: 13 [12800/60000 (21%)]	Loss: 0.188281	训练正确率: 97.26%	校验正确率: 97.48%
# (tensor(4862), 5000)
# 训练周期: 13 [19200/60000 (32%)]	Loss: 0.025687	训练正确率: 97.18%	校验正确率: 97.24%
# (tensor(4874), 5000)
# 训练周期: 13 [25600/60000 (43%)]	Loss: 0.048437	训练正确率: 97.21%	校验正确率: 97.48%
# (tensor(4880), 5000)
# 训练周期: 13 [32000/60000 (53%)]	Loss: 0.052800	训练正确率: 97.19%	校验正确率: 97.60%
# (tensor(4859), 5000)
# 训练周期: 13 [38400/60000 (64%)]	Loss: 0.159672	训练正确率: 97.21%	校验正确率: 97.18%
# (tensor(4866), 5000)
# 训练周期: 13 [44800/60000 (75%)]	Loss: 0.048357	训练正确率: 97.25%	校验正确率: 97.32%
# (tensor(4877), 5000)
# 训练周期: 13 [51200/60000 (85%)]	Loss: 0.034590	训练正确率: 97.23%	校验正确率: 97.54%
# (tensor(4881), 5000)
# 训练周期: 13 [57600/60000 (96%)]	Loss: 0.052840	训练正确率: 97.29%	校验正确率: 97.62%
# (tensor(4864), 5000)
# 训练周期: 14 [0/60000 (0%)]	Loss: 0.052841	训练正确率: 98.44%	校验正确率: 97.28%
# (tensor(4879), 5000)
# 训练周期: 14 [6400/60000 (11%)]	Loss: 0.046083	训练正确率: 97.32%	校验正确率: 97.58%
# (tensor(4881), 5000)
# 训练周期: 14 [12800/60000 (21%)]	Loss: 0.202466	训练正确率: 97.51%	校验正确率: 97.62%
# (tensor(4876), 5000)
# 训练周期: 14 [19200/60000 (32%)]	Loss: 0.128716	训练正确率: 97.50%	校验正确率: 97.52%
# (tensor(4876), 5000)
# 训练周期: 14 [25600/60000 (43%)]	Loss: 0.052706	训练正确率: 97.43%	校验正确率: 97.52%
# (tensor(4870), 5000)
# 训练周期: 14 [32000/60000 (53%)]	Loss: 0.129708	训练正确率: 97.42%	校验正确率: 97.40%
# (tensor(4870), 5000)
# 训练周期: 14 [38400/60000 (64%)]	Loss: 0.065336	训练正确率: 97.42%	校验正确率: 97.40%
# (tensor(4874), 5000)
# 训练周期: 14 [44800/60000 (75%)]	Loss: 0.032177	训练正确率: 97.47%	校验正确率: 97.48%
# (tensor(4895), 5000)
# 训练周期: 14 [51200/60000 (85%)]	Loss: 0.021131	训练正确率: 97.45%	校验正确率: 97.90%
# (tensor(4883), 5000)
# 训练周期: 14 [57600/60000 (96%)]	Loss: 0.043514	训练正确率: 97.48%	校验正确率: 97.66%
# (tensor(4872), 5000)
# 训练周期: 15 [0/60000 (0%)]	Loss: 0.043559	训练正确率: 98.44%	校验正确率: 97.44%
# (tensor(4870), 5000)
# 训练周期: 15 [6400/60000 (11%)]	Loss: 0.110082	训练正确率: 97.54%	校验正确率: 97.40%
# (tensor(4884), 5000)
# 训练周期: 15 [12800/60000 (21%)]	Loss: 0.081239	训练正确率: 97.58%	校验正确率: 97.68%
# (tensor(4885), 5000)
# 训练周期: 15 [19200/60000 (32%)]	Loss: 0.119790	训练正确率: 97.61%	校验正确率: 97.70%
# (tensor(4874), 5000)
# 训练周期: 15 [25600/60000 (43%)]	Loss: 0.087909	训练正确率: 97.56%	校验正确率: 97.48%
# (tensor(4885), 5000)
# 训练周期: 15 [32000/60000 (53%)]	Loss: 0.136040	训练正确率: 97.55%	校验正确率: 97.70%
# (tensor(4864), 5000)
# 训练周期: 15 [38400/60000 (64%)]	Loss: 0.167996	训练正确率: 97.60%	校验正确率: 97.28%
# (tensor(4874), 5000)
# 训练周期: 15 [44800/60000 (75%)]	Loss: 0.060893	训练正确率: 97.56%	校验正确率: 97.48%
# (tensor(4888), 5000)
# 训练周期: 15 [51200/60000 (85%)]	Loss: 0.097088	训练正确率: 97.56%	校验正确率: 97.76%
# (tensor(4866), 5000)
# 训练周期: 15 [57600/60000 (96%)]	Loss: 0.055683	训练正确率: 97.56%	校验正确率: 97.32%
# (tensor(4881), 5000)
# 训练周期: 16 [0/60000 (0%)]	Loss: 0.082194	训练正确率: 95.31%	校验正确率: 97.62%
# (tensor(4877), 5000)
# 训练周期: 16 [6400/60000 (11%)]	Loss: 0.032870	训练正确率: 97.69%	校验正确率: 97.54%
# (tensor(4888), 5000)
# 训练周期: 16 [12800/60000 (21%)]	Loss: 0.011650	训练正确率: 97.61%	校验正确率: 97.76%
# (tensor(4877), 5000)
# 训练周期: 16 [19200/60000 (32%)]	Loss: 0.073810	训练正确率: 97.51%	校验正确率: 97.54%
# (tensor(4883), 5000)
# 训练周期: 16 [25600/60000 (43%)]	Loss: 0.107266	训练正确率: 97.49%	校验正确率: 97.66%
# (tensor(4888), 5000)
# 训练周期: 16 [32000/60000 (53%)]	Loss: 0.038120	训练正确率: 97.47%	校验正确率: 97.76%
# (tensor(4886), 5000)
# 训练周期: 16 [38400/60000 (64%)]	Loss: 0.016516	训练正确率: 97.48%	校验正确率: 97.72%
# (tensor(4882), 5000)
# 训练周期: 16 [44800/60000 (75%)]	Loss: 0.072961	训练正确率: 97.49%	校验正确率: 97.64%
# (tensor(4874), 5000)
# 训练周期: 16 [51200/60000 (85%)]	Loss: 0.200313	训练正确率: 97.52%	校验正确率: 97.48%
# (tensor(4896), 5000)
# 训练周期: 16 [57600/60000 (96%)]	Loss: 0.065180	训练正确率: 97.53%	校验正确率: 97.92%
# (tensor(4887), 5000)
# 训练周期: 17 [0/60000 (0%)]	Loss: 0.062308	训练正确率: 96.88%	校验正确率: 97.74%
# (tensor(4884), 5000)
# 训练周期: 17 [6400/60000 (11%)]	Loss: 0.221596	训练正确率: 97.60%	校验正确率: 97.68%
# (tensor(4890), 5000)
# 训练周期: 17 [12800/60000 (21%)]	Loss: 0.041772	训练正确率: 97.70%	校验正确率: 97.80%
# (tensor(4888), 5000)
# 训练周期: 17 [19200/60000 (32%)]	Loss: 0.017252	训练正确率: 97.71%	校验正确率: 97.76%
# (tensor(4895), 5000)
# 训练周期: 17 [25600/60000 (43%)]	Loss: 0.083317	训练正确率: 97.69%	校验正确率: 97.90%
# (tensor(4872), 5000)
# 训练周期: 17 [32000/60000 (53%)]	Loss: 0.188945	训练正确率: 97.70%	校验正确率: 97.44%
# (tensor(4892), 5000)
# 训练周期: 17 [38400/60000 (64%)]	Loss: 0.061854	训练正确率: 97.71%	校验正确率: 97.84%
# (tensor(4893), 5000)
# 训练周期: 17 [44800/60000 (75%)]	Loss: 0.077527	训练正确率: 97.75%	校验正确率: 97.86%
# (tensor(4885), 5000)
# 训练周期: 17 [51200/60000 (85%)]	Loss: 0.159092	训练正确率: 97.74%	校验正确率: 97.70%
# (tensor(4877), 5000)
# 训练周期: 17 [57600/60000 (96%)]	Loss: 0.063238	训练正确率: 97.79%	校验正确率: 97.54%
# (tensor(4876), 5000)
# 训练周期: 18 [0/60000 (0%)]	Loss: 0.085831	训练正确率: 96.88%	校验正确率: 97.52%
# (tensor(4900), 5000)
# 训练周期: 18 [6400/60000 (11%)]	Loss: 0.108891	训练正确率: 97.35%	校验正确率: 98.00%
# (tensor(4880), 5000)
# 训练周期: 18 [12800/60000 (21%)]	Loss: 0.049760	训练正确率: 97.58%	校验正确率: 97.60%
# (tensor(4872), 5000)
# 训练周期: 18 [19200/60000 (32%)]	Loss: 0.065244	训练正确率: 97.62%	校验正确率: 97.44%
# (tensor(4900), 5000)
# 训练周期: 18 [25600/60000 (43%)]	Loss: 0.088614	训练正确率: 97.64%	校验正确率: 98.00%
# (tensor(4881), 5000)
# 训练周期: 18 [32000/60000 (53%)]	Loss: 0.017265	训练正确率: 97.73%	校验正确率: 97.62%
# (tensor(4890), 5000)
# 训练周期: 18 [38400/60000 (64%)]	Loss: 0.010854	训练正确率: 97.74%	校验正确率: 97.80%
# (tensor(4899), 5000)
# 训练周期: 18 [44800/60000 (75%)]	Loss: 0.010400	训练正确率: 97.76%	校验正确率: 97.98%
# (tensor(4892), 5000)
# 训练周期: 18 [51200/60000 (85%)]	Loss: 0.167393	训练正确率: 97.73%	校验正确率: 97.84%
# (tensor(4895), 5000)
# 训练周期: 18 [57600/60000 (96%)]	Loss: 0.030271	训练正确率: 97.75%	校验正确率: 97.90%
# (tensor(4889), 5000)
# 训练周期: 19 [0/60000 (0%)]	Loss: 0.018012	训练正确率: 100.00%	校验正确率: 97.78%
# (tensor(4896), 5000)
# 训练周期: 19 [6400/60000 (11%)]	Loss: 0.060696	训练正确率: 97.71%	校验正确率: 97.92%
# (tensor(4883), 5000)
# 训练周期: 19 [12800/60000 (21%)]	Loss: 0.243506	训练正确率: 97.85%	校验正确率: 97.66%
# (tensor(4891), 5000)
# 训练周期: 19 [19200/60000 (32%)]	Loss: 0.160556	训练正确率: 97.78%	校验正确率: 97.82%
# (tensor(4899), 5000)
# 训练周期: 19 [25600/60000 (43%)]	Loss: 0.113803	训练正确率: 97.81%	校验正确率: 97.98%
# (tensor(4884), 5000)
# 训练周期: 19 [32000/60000 (53%)]	Loss: 0.067914	训练正确率: 97.86%	校验正确率: 97.68%
# (tensor(4904), 5000)
# 训练周期: 19 [38400/60000 (64%)]	Loss: 0.033967	训练正确率: 97.83%	校验正确率: 98.08%
# (tensor(4886), 5000)
# 训练周期: 19 [44800/60000 (75%)]	Loss: 0.068389	训练正确率: 97.88%	校验正确率: 97.72%
# (tensor(4898), 5000)
# 训练周期: 19 [51200/60000 (85%)]	Loss: 0.044667	训练正确率: 97.85%	校验正确率: 97.96%
# (tensor(4889), 5000)
# 训练周期: 19 [57600/60000 (96%)]	Loss: 0.067422	训练正确率: 97.85%	校验正确率: 97.78%

# %%
#绘制训练过程的误差曲线，校验集和测试集上的错误率。
plt.figure(figsize = (10, 7))
plt.plot(record) #record记载了每一个打印周期记录的训练和校验数据集上的准确度
plt.xlabel('Steps')
plt.ylabel('Error rate')
# Out:
# Text(0, 0.5, 'Error rate')

# %% [markdown]
# ### 2.3 在测试集上进行分类

# %%
#在测试集上分批运行，并计算总的正确率
net.eval() #标志模型当前为运行阶段
vals = [] #记录准确率所用列表

#对测试数据集进行循环
for data, target in test_loader:
    data, target = data.clone().detach().requires_grad_(True), target.clone().detach()
    output = net(data) #将特征数据喂入网络，得到分类的输出
    val = rightness(output, target) #获得正确样本数以及总样本数
    vals.append(val) #记录结果

#计算准确率
rights = (sum([tup[0] for tup in vals]), sum([tup[1] for tup in vals]))
right_rate = 100. * rights[0].numpy() / rights[1]
print(right_rate)
# Out:
# 99.02

# %%
#随便从测试集中读入一张图片，并检验模型的分类结果，并绘制出来
idx = 4000
muteimg = test_dataset[idx][0].numpy()
plt.imshow(muteimg[0,...])
print('标签是：',test_dataset[idx][1])
# Out:
# 标签是： 9
